# %% [markdown]
# <a href="https://colab.research.google.com/github/Luc4sL4idens/CIENCIA-DE-DADOS-E-SISTEMAS-INTELIGENTE/blob/main/AvaliacaoAlgoritmos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Avaliação dos algoritmos ##
#
# * Árvores de Decisão: 98.20
# * Random Forest: 98.40
# * KNN: 98.60
# * Regressão Logística: 96.40
# * SVM: 98.80
# * Redes Neurais: 99.60

# %%
import pickle
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
## importar numpie
from numpy import mean

# %%
from google.colab import drive
drive.mount('/content/drive')
caminho = "/content/drive/MyDrive/6°SEM/CIÊNCIA DE DADOS E SISTEMAS INTELIGENTE/dados/"
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Base - Credit Data ##

# %%
with open(caminho +'credit_data.pkl', 'rb') as f:
  x_credit_treinamento, y_credit_treinamento, x_credit_teste, y_credit_teste = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# /tmp/ipython-input-3551325160.py in <cell line: 0>()
# ----> 1 with open(caminho, 'rb') as f:
#       2   x_credit_treinamento, y_credit_treinamento, x_credit_teste, y_credit_teste = pickle.load(f)
#
# IsADirectoryError: [Errno 21] Is a directory: '/content/drive/MyDrive/6°SEM/CIÊNCIA DE DADOS E SISTEMAS INTELIGENTE/dados/'

# %%
x_credit_treinamento.shape, y_credit_treinamento.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3471726692.py in <cell line: 0>()
# ----> 1 x_credit_treinamento.shape, y_credit_treinamento.shape
#
# NameError: name 'x_credit_treinamento' is not defined

# %%
x_credit_teste.shape, y_credit_teste.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3147271940.py in <cell line: 0>()
# ----> 1 x_credit_teste.shape, y_credit_teste.shape
#
# NameError: name 'x_credit_teste' is not defined
